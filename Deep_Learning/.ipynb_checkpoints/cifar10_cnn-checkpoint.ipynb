# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 41s 0us/step

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()

model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.25))

model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.25))

model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.25))

model.add(Conv2D(filters=128, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(600, activation='relu'))
model.add(Dropout(0.25))

model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_34 (Conv2D)           (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_34 (MaxPooling (None, 16, 16, 16)        0
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_35 (MaxPooling (None, 8, 8, 32)          0
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_36 (MaxPooling (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 4, 4, 128)         32896
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 2, 2, 128)         0
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 512)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 600)               307800
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 600)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 10)                6010
# =================================================================
# Total params: 357,250
# Trainable params: 357,250
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=50, epochs=50,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/50
#  - 15s - loss: 1.7772 - acc: 0.3375 - val_loss: 1.5645 - val_acc: 0.4280
#
# Epoch 00001: val_loss improved from inf to 1.56447, saving model to model.weights.best.hdf5
# Epoch 2/50
#  - 14s - loss: 1.4839 - acc: 0.4541 - val_loss: 1.3452 - val_acc: 0.5122
#
# Epoch 00002: val_loss improved from 1.56447 to 1.34516, saving model to model.weights.best.hdf5
# Epoch 3/50
#  - 14s - loss: 1.3803 - acc: 0.4981 - val_loss: 1.2499 - val_acc: 0.5420
#
# Epoch 00003: val_loss improved from 1.34516 to 1.24990, saving model to model.weights.best.hdf5
# Epoch 4/50
#  - 14s - loss: 1.3220 - acc: 0.5210 - val_loss: 1.2160 - val_acc: 0.5602
#
# Epoch 00004: val_loss improved from 1.24990 to 1.21600, saving model to model.weights.best.hdf5
# Epoch 5/50
#  - 15s - loss: 1.2678 - acc: 0.5396 - val_loss: 1.1514 - val_acc: 0.5798
#
# Epoch 00005: val_loss improved from 1.21600 to 1.15144, saving model to model.weights.best.hdf5
# Epoch 6/50
#  - 15s - loss: 1.2296 - acc: 0.5559 - val_loss: 1.0954 - val_acc: 0.6064
#
# Epoch 00006: val_loss improved from 1.15144 to 1.09539, saving model to model.weights.best.hdf5
# Epoch 7/50
#  - 29s - loss: 1.2045 - acc: 0.5640 - val_loss: 1.1385 - val_acc: 0.5896
#
# Epoch 00007: val_loss did not improve from 1.09539
# Epoch 8/50
#  - 14s - loss: 1.1767 - acc: 0.5741 - val_loss: 1.0484 - val_acc: 0.6208
#
# Epoch 00008: val_loss improved from 1.09539 to 1.04835, saving model to model.weights.best.hdf5
# Epoch 9/50
#  - 14s - loss: 1.1571 - acc: 0.5821 - val_loss: 1.1012 - val_acc: 0.5994
#
# Epoch 00009: val_loss did not improve from 1.04835
# Epoch 10/50
#  - 15s - loss: 1.1383 - acc: 0.5886 - val_loss: 1.0666 - val_acc: 0.6168
#
# Epoch 00010: val_loss did not improve from 1.04835
# Epoch 11/50
#  - 15s - loss: 1.1147 - acc: 0.6004 - val_loss: 1.0333 - val_acc: 0.6248
#
# Epoch 00011: val_loss improved from 1.04835 to 1.03332, saving model to model.weights.best.hdf5
# Epoch 12/50
#  - 46s - loss: 1.0956 - acc: 0.6070 - val_loss: 0.9928 - val_acc: 0.6418
#
# Epoch 00012: val_loss improved from 1.03332 to 0.99277, saving model to model.weights.best.hdf5
# Epoch 13/50
#  - 16s - loss: 1.0879 - acc: 0.6103 - val_loss: 1.1230 - val_acc: 0.5932
#
# Epoch 00013: val_loss did not improve from 0.99277
# Epoch 14/50
#  - 14s - loss: 1.0713 - acc: 0.6148 - val_loss: 1.0007 - val_acc: 0.6474
#
# Epoch 00014: val_loss did not improve from 0.99277
# Epoch 15/50
#  - 14s - loss: 1.0662 - acc: 0.6182 - val_loss: 0.9865 - val_acc: 0.6454
#
# Epoch 00015: val_loss improved from 0.99277 to 0.98652, saving model to model.weights.best.hdf5
# Epoch 16/50
#  - 15s - loss: 1.0560 - acc: 0.6224 - val_loss: 1.0279 - val_acc: 0.6274
#
# Epoch 00016: val_loss did not improve from 0.98652
# Epoch 17/50
#  - 15s - loss: 1.0443 - acc: 0.6236 - val_loss: 1.0037 - val_acc: 0.6396
#
# Epoch 00017: val_loss did not improve from 0.98652
# Epoch 18/50
#  - 15s - loss: 1.0369 - acc: 0.6275 - val_loss: 1.0302 - val_acc: 0.6246
#
# Epoch 00018: val_loss did not improve from 0.98652
# Epoch 19/50
#  - 15s - loss: 1.0354 - acc: 0.6288 - val_loss: 1.0052 - val_acc: 0.6390
#
# Epoch 00019: val_loss did not improve from 0.98652
# Epoch 20/50
#  - 15s - loss: 1.0278 - acc: 0.6330 - val_loss: 0.9805 - val_acc: 0.6450
#
# Epoch 00020: val_loss improved from 0.98652 to 0.98054, saving model to model.weights.best.hdf5
# Epoch 21/50
#  - 15s - loss: 1.0168 - acc: 0.6340 - val_loss: 0.9913 - val_acc: 0.6480
#
# Epoch 00021: val_loss did not improve from 0.98054
# Epoch 22/50
#  - 15s - loss: 1.0114 - acc: 0.6366 - val_loss: 0.9380 - val_acc: 0.6628
#
# Epoch 00022: val_loss improved from 0.98054 to 0.93802, saving model to model.weights.best.hdf5
# Epoch 23/50
#  - 27s - loss: 0.9952 - acc: 0.6457 - val_loss: 0.9032 - val_acc: 0.6798
#
# Epoch 00023: val_loss improved from 0.93802 to 0.90318, saving model to model.weights.best.hdf5
# Epoch 24/50
#  - 24s - loss: 1.0018 - acc: 0.6427 - val_loss: 0.9215 - val_acc: 0.6734
#
# Epoch 00024: val_loss did not improve from 0.90318
# Epoch 25/50
#  - 14s - loss: 0.9919 - acc: 0.6456 - val_loss: 0.9213 - val_acc: 0.6712
#
# Epoch 00025: val_loss did not improve from 0.90318
# Epoch 26/50
#  - 14s - loss: 0.9888 - acc: 0.6456 - val_loss: 0.9351 - val_acc: 0.6648
#
# Epoch 00026: val_loss did not improve from 0.90318
# Epoch 27/50
#  - 15s - loss: 0.9812 - acc: 0.6504 - val_loss: 1.0198 - val_acc: 0.6394
#
# Epoch 00027: val_loss did not improve from 0.90318
# Epoch 28/50
#  - 15s - loss: 0.9737 - acc: 0.6488 - val_loss: 0.9574 - val_acc: 0.6600
#
# Epoch 00028: val_loss did not improve from 0.90318
# Epoch 29/50
#  - 15s - loss: 0.9669 - acc: 0.6526 - val_loss: 0.9140 - val_acc: 0.6690
#
# Epoch 00029: val_loss did not improve from 0.90318
# Epoch 30/50
#  - 15s - loss: 0.9664 - acc: 0.6553 - val_loss: 0.9020 - val_acc: 0.6766
#
# Epoch 00030: val_loss improved from 0.90318 to 0.90204, saving model to model.weights.best.hdf5
# Epoch 31/50
#  - 15s - loss: 0.9565 - acc: 0.6567 - val_loss: 0.9177 - val_acc: 0.6690
#
# Epoch 00031: val_loss did not improve from 0.90204
# Epoch 32/50
#  - 15s - loss: 0.9530 - acc: 0.6570 - val_loss: 0.9304 - val_acc: 0.6692
#
# Epoch 00032: val_loss did not improve from 0.90204
# Epoch 33/50
#  - 15s - loss: 0.9533 - acc: 0.6574 - val_loss: 0.9542 - val_acc: 0.6606
#
# Epoch 00033: val_loss did not improve from 0.90204
# Epoch 34/50
#  - 15s - loss: 0.9474 - acc: 0.6619 - val_loss: 0.9803 - val_acc: 0.6494
#
# Epoch 00034: val_loss did not improve from 0.90204
# Epoch 35/50
#  - 15s - loss: 0.9502 - acc: 0.6595 - val_loss: 0.9100 - val_acc: 0.6776
#
# Epoch 00035: val_loss did not improve from 0.90204
# Epoch 36/50
#  - 15s - loss: 0.9461 - acc: 0.6644 - val_loss: 0.8916 - val_acc: 0.6804
#
# Epoch 00036: val_loss improved from 0.90204 to 0.89161, saving model to model.weights.best.hdf5
# Epoch 37/50
#  - 15s - loss: 0.9381 - acc: 0.6651 - val_loss: 0.9237 - val_acc: 0.6626
#
# Epoch 00037: val_loss did not improve from 0.89161
# Epoch 38/50
#  - 15s - loss: 0.9402 - acc: 0.6635 - val_loss: 0.8655 - val_acc: 0.6996
#
# Epoch 00038: val_loss improved from 0.89161 to 0.86554, saving model to model.weights.best.hdf5
# Epoch 39/50
#  - 15s - loss: 0.9325 - acc: 0.6673 - val_loss: 0.9134 - val_acc: 0.6798
#
# Epoch 00039: val_loss did not improve from 0.86554
# Epoch 40/50
#  - 15s - loss: 0.9306 - acc: 0.6663 - val_loss: 0.8762 - val_acc: 0.6942
#
# Epoch 00040: val_loss did not improve from 0.86554
# Epoch 41/50
#  - 15s - loss: 0.9268 - acc: 0.6684 - val_loss: 0.9641 - val_acc: 0.6570
#
# Epoch 00041: val_loss did not improve from 0.86554
# Epoch 42/50
#  - 15s - loss: 0.9269 - acc: 0.6685 - val_loss: 0.9122 - val_acc: 0.6746
#
# Epoch 00042: val_loss did not improve from 0.86554
# Epoch 43/50
#  - 15s - loss: 0.9204 - acc: 0.6705 - val_loss: 1.1146 - val_acc: 0.6116
#
# Epoch 00043: val_loss did not improve from 0.86554
# Epoch 44/50
#  - 15s - loss: 0.9252 - acc: 0.6692 - val_loss: 0.9413 - val_acc: 0.6632
#
# Epoch 00044: val_loss did not improve from 0.86554
# Epoch 45/50
#  - 14s - loss: 0.9149 - acc: 0.6738 - val_loss: 0.9353 - val_acc: 0.6626
#
# Epoch 00045: val_loss did not improve from 0.86554
# Epoch 46/50
#  - 15s - loss: 0.9125 - acc: 0.6735 - val_loss: 0.8853 - val_acc: 0.6790
#
# Epoch 00046: val_loss did not improve from 0.86554
# Epoch 47/50
#  - 15s - loss: 0.9174 - acc: 0.6720 - val_loss: 0.9547 - val_acc: 0.6566
#
# Epoch 00047: val_loss did not improve from 0.86554
# Epoch 48/50
#  - 15s - loss: 0.9105 - acc: 0.6746 - val_loss: 0.9526 - val_acc: 0.6566
#
# Epoch 00048: val_loss did not improve from 0.86554
# Epoch 49/50
#  - 15s - loss: 0.9077 - acc: 0.6756 - val_loss: 0.9824 - val_acc: 0.6516
#
# Epoch 00049: val_loss did not improve from 0.86554
# Epoch 50/50
#  - 15s - loss: 0.9026 - acc: 0.6771 - val_loss: 0.9336 - val_acc: 0.6686
#
# Epoch 00050: val_loss did not improve from 0.86554

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.6838

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
